# %% [markdown]
# # XGBoost Regression
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/muhammadtalhaishtiaq/ai-orchestrator/blob/main/04-regression/08_xgboost_regression.ipynb)
#
# ## Objectives
# - Train an XGBoost regressor
# - Compare against a baseline
# - Inspect feature importance
# - Learn common hyperparameters

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression

np.random.seed(42)
sns.set_theme()

try:
    import xgboost as xgb
except ImportError:
    # !pip -q install xgboost
    import xgboost as xgb

print('Libraries loaded')

# %% [markdown]
# ## 1. Dataset
#
# We model housing price with a non-linear signal.

# %%
n_samples = 500
size = np.random.uniform(70, 260, n_samples)
bedrooms = np.random.randint(1, 6, n_samples)
age = np.random.uniform(0, 60, n_samples)
distance = np.random.uniform(1, 35, n_samples)
schools = np.random.uniform(1, 10, n_samples)

price = (
800
17000
600
900
5000
) + 7000 * np.sin(size / 20) + np.random.normal(0, 22000, n_samples)

df = pd.DataFrame({
    'bedrooms': bedrooms,
    'distance': distance,
    'price': price

# %% [markdown]
# ## 4. Feature Importance

# %%
importance = pd.DataFrame({
    'importance': xgb_model.feature_importances_
,
,
,
,
4
,
,
,
,
,

: 
,
: {
: 

: [
5

: 
,
: {
: 

: [
6
,
,
,
,
,

: {
: {
: 

: 4,
: 5
