# %% [markdown]
# # Gradient Boosting Regression
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/muhammadtalhaishtiaq/ai-orchestrator/blob/main/04-regression/07_gradient_boosting_regression.ipynb)
#
# ## Objectives
# - Understand boosting for regression
# - Train a GradientBoostingRegressor
# - Tune key hyperparameters
# - Compare with a linear baseline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor

np.random.seed(42)
sns.set_theme()

print('Libraries loaded')

# %% [markdown]
# ## 1. Dataset
#
# We simulate housing data with non-linear effects.

# %%
n_samples = 400
size = np.random.uniform(60, 240, n_samples)
bedrooms = np.random.randint(1, 6, n_samples)
age = np.random.uniform(0, 50, n_samples)
distance = np.random.uniform(1, 30, n_samples)

price = (
850
18000
700
1000
) + 5000 * np.sin(size / 25) + np.random.normal(0, 20000, n_samples)

df = pd.DataFrame({
    'bedrooms': bedrooms,
    'distance': distance,

X = df[['size', 'bedrooms', 'age', 'distance']]
y = df['price']

X_train, X_test, y_train, y_test = train_test_split(
)

print(df.head())

# %% [markdown]
# ## 2. Baseline: Linear Regression

# %%
baseline = LinearRegression()
baseline.fit(X_train, y_train)
y_base = baseline.predict(X_test)

mae_base = mean_absolute_error(y_test, y_base)
rmse_base = mean_squared_error(y_test, y_base, squared=False)
r2_base = r2_score(y_test, y_base)

print('Baseline MAE:', round(mae_base, 2))
print('Baseline RMSE:', round(rmse_base, 2))
print('Baseline R2:', round(r2_base, 4))

# %% [markdown]
# ## 3. Gradient Boosting Model

# %%
gbr = GradientBoostingRegressor(
    learning_rate=0.05,
    random_state=42
,
,
,
,
,
,
,
,
2
,
2
,
4

: 
,
: {
: 

: [
4

: 
,
: {
: 

: [
}).sort_values('importance', ascending=False)
markdown
markdown
## 5. Actual vs Predicted
code
python
plt.figure(figsize=(6, 6))
plt.scatter(y_test, y_pred, alpha=0.7)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Gradient Boosting: Actual vs Predicted')
plt.tight_layout()
plt.show()
markdown
markdown
## Your Turn
- Increase n_estimators and reduce learning_rate
- Try max_depth = 2 and compare performance
- Add a new feature and retrain
markdown
markdown
## Summary
- Gradient boosting builds trees sequentially
- It captures non-linear patterns
- Tune n_estimators, learning_rate, and max_depth
