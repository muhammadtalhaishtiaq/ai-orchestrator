# %% [markdown]
# # Automated Eda Tools
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/muhammadtalhaishtiaq/ai-orchestrator/blob/main/02-exploratory-data-analysis/06_automated_eda_tools.ipynb)
#
# ---

# %% [markdown]
# ## 🎯 What are we learning today?
#
# In this notebook we'll tackle **Automated Eda Tools** — one of the most practical skills in machine learning.
#
# By the end you'll know exactly what it is, why it matters, and how to do it yourself.

# %% [markdown]
# ## 💡 The idea — in plain English
#
# Imagine you're a chef preparing a dish. Before you start cooking, you check your ingredients: are they fresh? Are any missing? Are they in the right form?
#
# **Automated Eda Tools** is exactly that — preparing your data so the model can actually learn from it.
#
# > **Difficulty:** Beginner  | **Time:** ~15 minutes
#
# Let's dig in.

# %% [markdown]
# ## ⚙️ Setup
#
# Just three libraries — nothing fancy.

# %%
import numpy as np          # numbers and arrays
import pandas as pd         # tables (DataFrames)
import matplotlib.pyplot as plt  # charts
import seaborn as sns        # nicer charts

plt.style.use('seaborn-v0_8-whitegrid')
print('✅ Setup done!')

# %% [markdown]
# ## 📦 Step 1 — Load the data
#
# We'll use a small, realistic dataset so you can see exactly what's happening. Think of this as a hiring dataset — age, salary, experience, hired or not.

# %%
# Sample dataset — realistic but small enough to understand completely
data = {
    'age':        [25, 30, 35, None, 45, 50, 28, None, 40, 33],
    'salary':     [50000, 60000, None, 80000, 90000, 100000, 55000, 75000, None, 65000],
    'experience': [2, 5, 8, 12, 15, 20, 3, 10, 14, 7],
    'hired':      [0, 1, 1, 1, 1, 1, 0, 1, 1, 1]
}

df = pd.DataFrame(data)
print(f'Dataset shape: {df.shape}')
print('\nFirst 5 rows:')
df.head()

# %% [markdown]
# ## 🔨 Step 2 — Apply Automated Eda Tools
#
# Let's look at what we're working with before making changes.

# %%
# Always inspect first — never change data blindly
print('Missing values per column:')
print(df.isnull().sum())

print('\nData types:')
print(df.dtypes)

print('\nBasic stats:')
df.describe()

# %% [markdown]
# ### Step 3 — Fix it

# %%
# Fill missing numerical values with the median
# (median is better than mean when you have outliers)
df_clean = df.fillna(df.median(numeric_only=True))

print('After cleaning:')
print('Missing values:', df_clean.isnull().sum().sum())
df_clean.head()

# %% [markdown]
# ## 📊 What did we get?
#
# Let's check the before vs after.

# %%
print('BEFORE — missing values:')
print(df.isnull().sum())

print('\nAFTER — missing values:')
print(df_clean.isnull().sum())

print('\n✅ Data is clean and ready for a model!')

# %% [markdown]
# ## 📈 Let's see it
#
# Visuals make it click faster than words.

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Left chart: where data was missing
missing_counts = df.isnull().sum()
axes[0].bar(missing_counts.index, missing_counts.values, color='#ef4444', alpha=0.8)
axes[0].set_title('Missing Values — Before Cleaning', fontsize=13, fontweight='bold')
axes[0].set_xlabel('Column')
axes[0].set_ylabel('Missing Count')

# Right chart: salary distribution after cleaning
axes[1].hist(df_clean['salary'], bins=8, color='#22c55e', edgecolor='white', alpha=0.9)
axes[1].set_title('Salary Distribution — After Cleaning', fontsize=13, fontweight='bold')
axes[1].set_xlabel('Salary ($)')
axes[1].set_ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## ✅ Quick recap
#
# Here's what we just did:
#
# - 🧠 **What**: Automated Eda Tools — preparing data so ML models can learn properly
# - 🔍 **Why**: Messy data → bad predictions, no matter how good your model is
# - 🛠️ **How**: Use pandas to inspect, clean, and verify your data
# - 📊 **Check**: Always visualize before and after
# - ⏭️ **Next step**: Try this on a real Kaggle dataset!

# %% [markdown]
# ## 🏋️ Your turn — 3 quick exercises

# %%
# Exercise 1: What percentage of values are missing in each column?
# Hint: df.isnull().mean() * 100
# --- YOUR CODE HERE ---


# Exercise 2: Instead of median, try filling with the MEAN. Does it change much?
# Hint: df.fillna(df.mean(numeric_only=True))
# --- YOUR CODE HERE ---


# Exercise 3: Drop ALL rows that have ANY missing values. How many rows remain?
# Hint: df.dropna()
# --- YOUR CODE HERE ---
